# %% [markdown]
# In this week's independent project, you will be working as a data scientist working for an electric car-sharing service company. You have been tasked to process stations data to understand electric car usage over time by solving for the following research question;
#
# Research Question
#
# Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018.
# Bonus Questions (Optional)
#
# What is the most popular hour for returning cars?
# What station is the most popular?
# Overall?
# At the most popular picking hour?
# What postal code is the most popular for picking up Blue cars? Does the most popular station belong to that postal code?
# Overall?
# At the most popular picking hour?
# Do the results change if you consider Utilib and Utilib 1.4 instead of Blue cars?

# %% [markdown]
# **PYTHON QUESTIONS**

# %%
# Importing the pandas library
# OUR CODE GOES HERE
import pandas as pd

# Importing the numpy library
#OUR CODE GOES HERE
import numpy as np

import datetime as dt

# %%
# Let's read the data from the CSV file and create the dataframe to be used
# OUR CODE GOES HERE
df = pd.read_csv('Autolib_dataset (2).csv', delimiter = ',')
df
# Out:
#                                  Address  Cars  ...  hour  minute
# 0                    2 Avenue de Suffren     0  ...    11      43
# 1              145 Rue Raymond Losserand     6  ...     7      24
# 2       2 Avenue John Fitzgerald Kennedy     3  ...    20      14
# 3                 51 Rue Eug̬ne Oudin̩     3  ...     4      37
# 4     6 avenue de la Porte de Champerret     3  ...    17      23
# ...                                  ...   ...  ...   ...     ...
# 4995                 8 avenue M̩nelotte     2  ...    11      26
# 4996                   37 rue de Dantzig     4  ...    16      56
# 4997                      142 rue du Bac     1  ...     7       1
# 4998         2 avenue du Val de Fontenay     2  ...    17      27
# 4999                 5 Rue Henry Brisson     4  ...    10       2
#
# [5000 rows x 25 columns]

# %%
#Joining our year,month,day,hour,minute,columns
df['date'] = pd.to_datetime(df[['year','month','day','hour','minute']])
df['date_new'] = df['date'].dt.strftime('%Y:%m:%d:%H:%M')
print (df)
# Out:
#                                  Address  ...          date_new
# 0                    2 Avenue de Suffren  ...  2018:04:08:11:43
# 1              145 Rue Raymond Losserand  ...  2018:04:06:07:24
# 2       2 Avenue John Fitzgerald Kennedy  ...  2018:04:03:20:14
# 3                 51 Rue Eug̬ne Oudin̩  ...  2018:04:04:04:37
# 4     6 avenue de la Porte de Champerret  ...  2018:04:08:17:23
# ...                                  ...  ...               ...
# 4995                 8 avenue M̩nelotte  ...  2018:04:06:11:26
# 4996                   37 rue de Dantzig  ...  2018:04:04:16:56
# 4997                      142 rue du Bac  ...  2018:04:01:07:01
# 4998         2 avenue du Val de Fontenay  ...  2018:04:04:17:27
# 4999                 5 Rue Henry Brisson  ...  2018:04:08:10:02
#
# [5000 rows x 27 columns]

# %%
df.head(10)
# Out:
#                               Address  ...          date_new
# 0                 2 Avenue de Suffren  ...  2018:04:08:11:43
# 1           145 Rue Raymond Losserand  ...  2018:04:06:07:24
# 2    2 Avenue John Fitzgerald Kennedy  ...  2018:04:03:20:14
# 3              51 Rue Eug̬ne Oudin̩  ...  2018:04:04:04:37
# 4  6 avenue de la Porte de Champerret  ...  2018:04:08:17:23
# 5                8 Boulevard Voltaire  ...  2018:04:06:07:02
# 6                      37 rue Leblanc  ...  2018:04:08:18:20
# 7         17 Rue des Luaps Prolong̩e  ...  2018:04:04:22:13
# 8               34 avenue Jean Moulin  ...  2018:04:02:22:58
# 9        41 boulevard de Rochechouart  ...  2018:04:04:15:02
#
# [10 rows x 27 columns]

# %%
df.count()
# Out:
# Address                5000
# Cars                   5000
# Bluecar counter        5000
# Utilib counter         5000
# Utilib 1.4 counter     5000
# Charge Slots           5000
# Charging Status        5000
# City                   5000
# Displayed comment       111
# ID                     5000
# Kind                   5000
# Geo point              5000
# Postal code            5000
# Public name            5000
# Rental status          5000
# Scheduled at             47
# Slots                  5000
# Station type           5000
# Status                 5000
# Subscription status    5000
# year                   5000
# month                  5000
# day                    5000
# hour                   5000
# minute                 5000
# date                   5000
# date_new               5000
# dtype: int64

# %%
df.shape
# Out:
# (5000, 27)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Address              5000 non-null   object
#  1   Cars                 5000 non-null   int64
#  2   Bluecar counter      5000 non-null   int64
#  3   Utilib counter       5000 non-null   int64
#  4   Utilib 1.4 counter   5000 non-null   int64
#  5   Charge Slots         5000 non-null   int64
#  6   Charging Status      5000 non-null   object
#  7   City                 5000 non-null   object
#  8   Displayed comment    111 non-null    object
#  9   ID                   5000 non-null   object
#  10  Kind                 5000 non-null   object
#  11  Geo point            5000 non-null   object
#  12  Postal code          5000 non-null   int64
#  13  Public name          5000 non-null   object
#  14  Rental status        5000 non-null   object
# ...

# %%
df.describe()
# Out:
#               Cars  Bluecar counter  ...         hour       minute
# count  5000.000000      5000.000000  ...  5000.000000  5000.000000
# mean      2.333600         2.333600  ...    11.509200    29.270000
# std       2.035274         2.035274  ...     6.893549    17.231741
# min       0.000000         0.000000  ...     0.000000     0.000000
# 25%       0.000000         0.000000  ...     6.000000    14.000000
# 50%       2.000000         2.000000  ...    11.000000    29.000000
# 75%       4.000000         4.000000  ...    18.000000    44.000000
# max       7.000000         7.000000  ...    23.000000    59.000000
#
# [8 rows x 12 columns]

# %%
df.isna()
# Out:
#       Address   Cars  Bluecar counter  ...  minute   date  date_new
# 0       False  False            False  ...   False  False     False
# 1       False  False            False  ...   False  False     False
# 2       False  False            False  ...   False  False     False
# 3       False  False            False  ...   False  False     False
# 4       False  False            False  ...   False  False     False
# ...       ...    ...              ...  ...     ...    ...       ...
# 4995    False  False            False  ...   False  False     False
# 4996    False  False            False  ...   False  False     False
# 4997    False  False            False  ...   False  False     False
# 4998    False  False            False  ...   False  False     False
# 4999    False  False            False  ...   False  False     False
#
# [5000 rows x 27 columns]

# %%
#dropping columns with null values
df.drop(['Scheduled at','Displayed comment'], axis = 1)
# Out:
#                                  Address  ...          date_new
# 0                    2 Avenue de Suffren  ...  2018:04:08:11:43
# 1              145 Rue Raymond Losserand  ...  2018:04:06:07:24
# 2       2 Avenue John Fitzgerald Kennedy  ...  2018:04:03:20:14
# 3                 51 Rue Eug̬ne Oudin̩  ...  2018:04:04:04:37
# 4     6 avenue de la Porte de Champerret  ...  2018:04:08:17:23
# ...                                  ...  ...               ...
# 4995                 8 avenue M̩nelotte  ...  2018:04:06:11:26
# 4996                   37 rue de Dantzig  ...  2018:04:04:16:56
# 4997                      142 rue du Bac  ...  2018:04:01:07:01
# 4998         2 avenue du Val de Fontenay  ...  2018:04:04:17:27
# 4999                 5 Rue Henry Brisson  ...  2018:04:08:10:02
#
# [5000 rows x 23 columns]

# %%
df[['Bluecar counter','Subscription status']].value_counts()
# Out:
# Bluecar counter  Subscription status
# 0                nonexistent            1326
# 3                nonexistent             615
# 1                nonexistent             609
# 4                nonexistent             578
# 2                nonexistent             572
# 5                nonexistent             527
# 6                nonexistent             327
# 0                broken                   61
#                  operational              60
# 2                operational              44
# 3                operational              43
# 4                operational              39
# 1                operational              39
# 7                nonexistent              39
# 5                operational              31
# 4                broken                   19
# 5                broken                   16
# 1                broken                   15
# 3                broken                   14
# 2                broken                   12
# ...

# %%
df['Cars'].max()
# Out:
# 7

# %%
df[['Utilib 1.4 counter','Subscription status']].value_counts()
# Out:
# Utilib 1.4 counter  Subscription status
# 0                   nonexistent            4065
# 1                   nonexistent             486
# 0                   operational             238
#                     broken                  128
# 2                   nonexistent              41
# 1                   operational              26
#                     broken                   13
# 3                   nonexistent               1
#                     broken                    1
# 2                   broken                    1
# dtype: int64

# %%
df[['Utilib counter','Subscription status']].value_counts()
# Out:
# Utilib counter  Subscription status
# 0               nonexistent            4328
# 1               nonexistent             253
# 0               operational             248
#                 broken                  138
# 1               operational              16
# 2               nonexistent              12
# 1               broken                    5
# dtype: int64

# %%
df['day']
# Out:
# 0       8
# 1       6
# 2       3
# 3       4
# 4       8
#        ..
# 4995    6
# 4996    4
# 4997    1
# 4998    4
# 4999    8
# Name: day, Length: 5000, dtype: int64

# %%
#Getting max hour
df['date_new'].max()
# Out:
# '2018:04:09:23:58'

# %%
#Identify the most popular hour of the day for picking up a shared electric car (Bluecar) in the city of Paris over the month of April 2018. Bonus Questions (Optional



df.groupby(['Bluecar counter','date_new','City']).size().sort_values(ascending=False)
# Out:
# Bluecar counter  date_new          City
# 0                2018:04:08:16:31  Paris                   3
#                  2018:04:07:20:14  Paris                   3
# 1                2018:04:05:18:58  Paris                   2
# 0                2018:04:08:18:20  Paris                   2
#                  2018:04:01:13:13  Paris                   2
#                                                           ..
# 3                2018:04:09:03:03  Paris                   1
#                  2018:04:09:03:20  Bagnolet                1
#                  2018:04:09:03:35  Boulogne-Billancourt    1
#                  2018:04:09:04:07  Paris                   1
# 0                2018:04:01:00:00  Paris                   1
# Length: 4925, dtype: int64

# %%
#What is the most popular hour for returning cars?Overall?

df([['hour','Cars']]df.iloc['Subscription status'] == 'broken']).sort_values(ascending=False)
# Out:
#   File "<ipython-input-24-c1b8df733426>", line 3
#     df([['hour','Cars']]df.iloc['Subscription status'] == 'broken']).sort_values(ascending=False)
#                          ^
# SyntaxError: invalid syntax

# %%
0#What station is the most popular?0verall?
df[['Station type']]df.[['Charging Status'] == 'operational'].value_counts()
# Out:
#   File "<ipython-input-23-a33c41a027a6>", line 2
#     df[['Station type']]df.iloc [['Charging Status'] == 'operational'].value_counts()
#                          ^
# SyntaxError: invalid syntax

# %%
#To prove our code
df.loc[df['Charging Status'] == 'operational']
# Out:
#                                Address  ...          date_new
# 1            145 Rue Raymond Losserand  ...  2018:04:06:07:24
# 2     2 Avenue John Fitzgerald Kennedy  ...  2018:04:03:20:14
# 3               51 Rue Eug̬ne Oudin̩  ...  2018:04:04:04:37
# 10                      14 rue Censier  ...  2018:04:01:04:39
# 14          8 Boulevard Richard Lenoir  ...  2018:04:06:08:00
# ...                                ...  ...               ...
# 4992                   3 avenue d'Ivry  ...  2018:04:09:23:01
# 4994                  15 rue de Rocroy  ...  2018:04:01:20:49
# 4996                 37 rue de Dantzig  ...  2018:04:04:16:56
# 4997                    142 rue du Bac  ...  2018:04:01:07:01
# 4999               5 Rue Henry Brisson  ...  2018:04:08:10:02
#
# [1995 rows x 27 columns]

# %%
df.head(10)

# %%
#Which station was popular At the most popular picking hour?


a=df.groupby('Station type')['date_new'].value_counts()
a.sort_values(ascending=False)
# Out:
# Station type  date_new
# station       2018:04:01:14:25    4
#               2018:04:01:16:02    4
#               2018:04:04:03:32    4
#               2018:04:06:05:52    4
#               2018:04:08:11:07    4
#                                  ..
#               2018:04:05:20:52    1
#               2018:04:05:20:50    1
#               2018:04:05:20:43    1
#               2018:04:05:20:33    1
#               2018:04:03:23:08    1
# Name: date_new, Length: 4247, dtype: int64

# %%
#What postal code is the most popular for picking up Blue cars? 


df[['Postal code']][df['Bluecar counter'] == True].value_counts()
# Out:
# Postal code
# 75015          39
# 75017          36
# 75013          36
# 75019          34
# 75016          30
#                ..
# 92400           1
# 93500           1
# 93370           1
# 91400           1
# 95880           1
# Length: 85, dtype: int64

# %%
df['Postal code'] = df['Postal code'].astype(int)

# %%
#Does the most popular station belong to that postal code?At the most popular picking hour?

c=df(['Station type'].groupby=df['hour'][df['Postal code'] == "75015"])\
c.sort_values(ascending=Flase)
# Out:
#   File "<ipython-input-70-c53e76da3aac>", line 3
#     c=df(['Station type'].groupby=df['hour'][df['Postal code'] == "75015"])c.sort_values(ascending=Flase)
#                                                                            ^
# SyntaxError: invalid syntax

# %%
#Do the results change if you consider Utilib and Utilib 1.4 instead of Blue cars?
